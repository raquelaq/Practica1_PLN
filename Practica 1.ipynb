# %%
from app.preprocesamiento import preprocess_docx
from app.BOW import *
from app.sim_coseno import calcular_similitud_coseno
import os

# %% [markdown]
# ## Preprocesamiento

# %%
input_path = "corpus"
output_path = "data"
stopwords_path = r"resources/stopwords-es.txt"

preprocess_docx(input_path, output_path, stopwords_path)
# Out:
#  Directorio de entrada: C:\Users\tomas\Desktop\PLN\PRÁCTICA 1\Practica1_PLN\corpus
# Directorio de salida: C:\Users\tomas\Desktop\PLN\PRÁCTICA 1\Practica1_PLN\data
#
# Procesado: doc01.docx → doc01_preprocessed.txt
# Procesado: doc02.docx → doc02_preprocessed.txt
# Procesado: doc03.docx → doc03_preprocessed.txt
# Procesado: doc04.docx → doc04_preprocessed.txt
# Procesado: doc05.docx → doc05_preprocessed.txt
# Procesado: doc06.docx → doc06_preprocessed.txt
# Procesado: doc07.docx → doc07_preprocessed.txt
# Procesado: doc08.docx → doc08_preprocessed.txt
# Procesado: doc09.docx → doc09_preprocessed.txt
# Procesado: doc10.docx → doc10_preprocessed.txt
# Procesado: doc11.docx → doc11_preprocessed.txt
# Procesado: doc12.docx → doc12_preprocessed.txt
#
# Preprocesamiento completado.

# %% [markdown]
# ## Bag of Words

# %%
vocab = make_vocab(output_path)
print(vocab[:30])
# Out:
# Procesado: doc01_preprocessed.txt
# Procesado: doc02_preprocessed.txt
# Procesado: doc03_preprocessed.txt
# Procesado: doc04_preprocessed.txt
# Procesado: doc05_preprocessed.txt
# Procesado: doc06_preprocessed.txt
# Procesado: doc07_preprocessed.txt
# Procesado: doc08_preprocessed.txt
# Procesado: doc09_preprocessed.txt
# Procesado: doc10_preprocessed.txt
# Procesado: doc11_preprocessed.txt
# Procesado: doc12_preprocessed.txt
#
# Tamaño del vocabulario: 365 palabras únicas
# ['actualizaciones', 'adopción', 'adquisición', 'afirman', 'agigantados', 'alta', 'amantes', 'ambas', 'amenazas', 'anunciado', 'anuncio', 'anunció', 'aplicaciones', 'aplicación', 'aporta', 'app', 'apps', 'aprovechar', 'ar', 'arduamente', 'arworld', 'asequible', 'auge', 'aumentada', 'aumentando', 'aumento', 'autenticación', 'automoción', 'automotrices', 'automovilística']

# %%
bow_df = make_bow(output_path, vocab)

bow_df
# Out:
# Matriz Bag-of-Words creada con tamaño (12, 365)
#                         actualizaciones  adopción  adquisición  afirman  \
# doc01_preprocessed.txt                0         0            0        0
# doc02_preprocessed.txt                0         0            0        1
# doc03_preprocessed.txt                0         0            0        0
# doc04_preprocessed.txt                0         0            0        0
# doc05_preprocessed.txt                0         1            1        0
# doc06_preprocessed.txt                0         0            0        0
# doc07_preprocessed.txt                0         0            0        0
# doc08_preprocessed.txt                0         0            0        0
# doc09_preprocessed.txt                0         1            0        0
# doc10_preprocessed.txt                0         0            0        0
# doc11_preprocessed.txt                1         0            0        0
# ...

# %% [markdown]
# ## Matriz de Similitud del Coseno

# %%
docs = sorted([f for f in os.listdir(output_path) if f.endswith('.txt')])

df_sim = calcular_similitud_coseno(bow_df, docs)

df_sim
# Out:
#                         doc01_preprocessed.txt  doc02_preprocessed.txt  \
# doc01_preprocessed.txt                1.000000                0.051709
# doc02_preprocessed.txt                0.051709                1.000000
# doc03_preprocessed.txt                0.000000                0.105021
# doc04_preprocessed.txt                0.056980                0.000000
# doc05_preprocessed.txt                0.019462                0.000000
# doc06_preprocessed.txt                0.119488                0.116510
# doc07_preprocessed.txt                0.071819                0.142976
# doc08_preprocessed.txt                0.017408                0.039606
# doc09_preprocessed.txt                0.000000                0.000000
# doc10_preprocessed.txt                0.055670                0.105550
# doc11_preprocessed.txt                0.148454                0.211100
# doc12_preprocessed.txt                0.087039                0.099015
#
# ...
